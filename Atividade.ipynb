# %% [markdown]
# <a href="https://colab.research.google.com/github/Samuel-Unemat/processamento-imagens/blob/main/Atividade.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install opencv-python numpy matplotlib
# Out:
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.12/dist-packages (4.13.0.92)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
repo_url = "https://github.com/Samuel-Unemat/processamento-imagens.git"

# !git clone {repo_url}
# Out:
# fatal: destination path 'processamento-imagens' already exists and is not an empty directory.

# %%
base_path = "/content/processamento-imagens/Imagens"

# Lista todas as imagens da pasta
imagens = os.listdir(base_path)

print("Imagens encontradas:", imagens)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_3482/2317988266.py in <cell line: 0>()
#       2
#       3 # Lista todas as imagens da pasta
# ----> 4 imagens = os.listdir(base_path)
#       5
#       6 print("Imagens encontradas:", imagens)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/processamento-imagens/Imagens'

# %%
img_path = os.path.join(base_path, "imagem1.jpg")

img = cv2.imread(img_path)

# Verificação
if img is None:
    print("Erro ao carregar a imagem. Verifique o nome/caminho.")
else:
    print("Imagem carregada com sucesso!")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3482/2741226790.py in <cell line: 0>()
#       1 img_path = os.path.join(base_path, "imagem1.jpg")
#       2
# ----> 3 img = cv2.imread(img_path)
#       4
#       5 # Verificação
#
# NameError: name 'cv2' is not defined

# %%
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img_rgb)
plt.title("Imagem carregada do GitHub")
plt.axis('off')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3482/699164815.py in <cell line: 0>()
# ----> 1 img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#       2
#       3 plt.imshow(img_rgb)
#       4 plt.title("Imagem carregada do GitHub")
#       5 plt.axis('off')
#
# NameError: name 'cv2' is not defined

# %%
imgs = []

for nome in imagens:
    caminho = os.path.join(base_path, nome)
    imagem = cv2.imread(caminho)

    if imagem is not None:
        imgs.append(imagem)

print(f"{len(imgs)} imagens carregadas com sucesso!")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3482/1589427071.py in <cell line: 0>()
#       1 imgs = []
#       2
# ----> 3 for nome in imagens:
#       4     caminho = os.path.join(base_path, nome)
#       5     imagem = cv2.imread(caminho)
#
# NameError: name 'imagens' is not defined

# %%
for i, imagem in enumerate(imgs):
    plt.figure()
    plt.imshow(cv2.cvtColor(imagem, cv2.COLOR_BGR2RGB))
    plt.title(f"Imagem {i+1}")
    plt.axis('off')

# %%
# EXERCÍCIO 1

img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)
plt.title("Imagem Original")
plt.axis('off')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3482/1606654553.py in <cell line: 0>()
#       1 # EXERCÍCIO 1
#       2
# ----> 3 img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#       4 plt.imshow(img_rgb)
#       5 plt.title("Imagem Original")
#
# NameError: name 'cv2' is not defined

# %%
# EXERCÍCIO 2

print("Shape:", img.shape)
print("Size:", img.size)
print("Dtype:", img.dtype)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3482/907335790.py in <cell line: 0>()
#       1 # EXERCÍCIO 2
#       2
# ----> 3 print("Shape:", img.shape)
#       4 print("Size:", img.size)
#       5 print("Dtype:", img.dtype)
#
# NameError: name 'img' is not defined

# %%
# EXERCÍCIO 3

cv2.imwrite('imagem_convertida.jpg', img)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3482/212806992.py in <cell line: 0>()
#       1 # EXERCÍCIO 3
#       2
# ----> 3 cv2.imwrite('imagem_convertida.jpg', img)
#
# NameError: name 'cv2' is not defined

# %%
# EXERCÍCIO 4

h, w, _ = img.shape
centro = img[h//2, w//2]
print("Pixel central (BGR):", centro)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3482/380461323.py in <cell line: 0>()
#       1 # EXERCÍCIO 4
#       2
# ----> 3 h, w, _ = img.shape
#       4 centro = img[h//2, w//2]
#       5 print("Pixel central (BGR):", centro)
#
# NameError: name 'img' is not defined

# %%
# EXERCÍCIO 5

img_mod = img.copy()
img_mod[0:100, 0:100] = (0, 255, 0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3482/2177508511.py in <cell line: 0>()
#       1 # EXERCÍCIO 5
#       2
# ----> 3 img_mod = img.copy()
#       4 img_mod[0:100, 0:100] = (0, 255, 0)
#
# NameError: name 'img' is not defined

# %%
# EXERCÍCIO 6

roi = img[100:300, 100:300]

plt.imshow(cv2.cvtColor(roi, cv2.COLOR_BGR2RGB))
plt.title("Recorte (ROI)")
plt.axis('off')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3482/2712904921.py in <cell line: 0>()
#       1 # EXERCÍCIO 6
#       2
# ----> 3 roi = img[100:300, 100:300]
#       4
#       5 plt.imshow(cv2.cvtColor(roi, cv2.COLOR_BGR2RGB))
#
# NameError: name 'img' is not defined

# %%
# EXERCÍCIO 7

b, g, r = cv2.split(img)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3482/2863185812.py in <cell line: 0>()
#       1 # EXERCÍCIO 7
#       2
# ----> 3 b, g, r = cv2.split(img)
#
# NameError: name 'cv2' is not defined

# %%
# EXERCÍCIO 8

plt.imshow(g, cmap='gray')
plt.title("Canal Verde")
plt.axis('off')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3482/2924342786.py in <cell line: 0>()
#       1 # EXERCÍCIO 8
#       2
# ----> 3 plt.imshow(g, cmap='gray')
#       4 plt.title("Canal Verde")
#       5 plt.axis('off')
#
# NameError: name 'plt' is not defined

# %%
# EXERCÍCIO 9

img_merge = cv2.merge([r, g, b])
plt.imshow(img_merge)
plt.title("Canais invertidos (R ↔ B)")
plt.axis('off')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3482/739315935.py in <cell line: 0>()
#       1 # EXERCÍCIO 9
#       2
# ----> 3 img_merge = cv2.merge([r, g, b])
#       4 plt.imshow(img_merge)
#       5 plt.title("Canais invertidos (R ↔ B)")
#
# NameError: name 'cv2' is not defined

# %%
# EXERCÍCIO 10

gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(gray, cmap='gray')
plt.title("Escala de Cinza")
plt.axis('off')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3482/2562033928.py in <cell line: 0>()
#       1 # EXERCÍCIO 10
#       2
# ----> 3 gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#       4 plt.imshow(gray, cmap='gray')
#       5 plt.title("Escala de Cinza")
#
# NameError: name 'cv2' is not defined

# %%
# EXERCÍCIO 11

hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
s = hsv[:, :, 1]

plt.imshow(s, cmap='gray')
plt.title("Canal Saturação (S)")
plt.axis('off')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3482/747581127.py in <cell line: 0>()
#       1 # EXERCÍCIO 11
#       2
# ----> 3 hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
#       4 s = hsv[:, :, 1]
#       5
#
# NameError: name 'cv2' is not defined

# %%
# EXERCÍCIO 12

bright = cv2.add(img, np.ones(img.shape, dtype='uint8') * 50)

plt.imshow(cv2.cvtColor(bright, cv2.COLOR_BGR2RGB))
plt.title("Imagem com brilho aumentado")
plt.axis('off')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3482/4142711871.py in <cell line: 0>()
#       1 # EXERCÍCIO 12
#       2
# ----> 3 bright = cv2.add(img, np.ones(img.shape, dtype='uint8') * 50)
#       4
#       5 plt.imshow(cv2.cvtColor(bright, cv2.COLOR_BGR2RGB))
#
# NameError: name 'cv2' is not defined

# %%
# EXERCÍCIO 13

img2 = cv2.resize(img, (img.shape[1], img.shape[0]))

blend = cv2.addWeighted(img, 0.5, img2, 0.5, 0)

plt.imshow(cv2.cvtColor(blend, cv2.COLOR_BGR2RGB))
plt.title("Mesclagem de imagens")
plt.axis('off')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3482/3660565058.py in <cell line: 0>()
#       1 # EXERCÍCIO 13
#       2
# ----> 3 img2 = cv2.resize(img, (img.shape[1], img.shape[0]))
#       4
#       5 blend = cv2.addWeighted(img, 0.5, img2, 0.5, 0)
#
# NameError: name 'cv2' is not defined

# %%
# EXERCÍCIO 14

neg = 255 - gray

plt.imshow(neg, cmap='gray')
plt.title("Negativo")
plt.axis('off')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3482/2066115001.py in <cell line: 0>()
#       1 # EXERCÍCIO 14
#       2
# ----> 3 neg = 255 - gray
#       4
#       5 plt.imshow(neg, cmap='gray')
#
# NameError: name 'gray' is not defined

# %%
# EXERCÍCIO 15

mask = np.zeros(gray.shape, dtype='uint8')
cv2.circle(mask, (w//2, h//2), 100, 255, -1)

res = cv2.bitwise_and(img, img, mask=mask)

plt.imshow(cv2.cvtColor(res, cv2.COLOR_BGR2RGB))
plt.title("Máscara circular")
plt.axis('off')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3482/1119398898.py in <cell line: 0>()
#       1 # EXERCÍCIO 15
#       2
# ----> 3 mask = np.zeros(gray.shape, dtype='uint8')
#       4 cv2.circle(mask, (w//2, h//2), 100, 255, -1)
#       5
#
# NameError: name 'np' is not defined

# %%
# EXERCÍCIO 16

small = cv2.resize(img, None, fx=0.3, fy=0.3)
print("Novo shape:", small.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3482/2355922846.py in <cell line: 0>()
#       1 # EXERCÍCIO 16
#       2
# ----> 3 small = cv2.resize(img, None, fx=0.3, fy=0.3)
#       4 print("Novo shape:", small.shape)
#
# NameError: name 'cv2' is not defined

# %%
# EXERCÍCIO 17

hist = cv2.calcHist([gray], [0], None, [256], [0, 256])
print("Histograma (primeiros valores):")
print(hist[:10])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3482/1823107493.py in <cell line: 0>()
#       1 # EXERCÍCIO 17
#       2
# ----> 3 hist = cv2.calcHist([gray], [0], None, [256], [0, 256])
#       4 print("Histograma (primeiros valores):")
#       5 print(hist[:10])
#
# NameError: name 'cv2' is not defined

# %%
# EXERCÍCIO 18

colors = ('b', 'g', 'r')

for i, col in enumerate(colors):
    hist = cv2.calcHist([img], [i], None, [256], [0, 256])
    plt.plot(hist)

plt.title("Histograma RGB")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3482/1375386870.py in <cell line: 0>()
#       4
#       5 for i, col in enumerate(colors):
# ----> 6     hist = cv2.calcHist([img], [i], None, [256], [0, 256])
#       7     plt.plot(hist)
#       8
#
# NameError: name 'cv2' is not defined

# %%
# EXERCÍCIO 19
# ================================
eq = cv2.equalizeHist(gray)

plt.imshow(eq, cmap='gray')
plt.title("Equalização de Histograma")
plt.axis('off')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3482/786643660.py in <cell line: 0>()
#       1 # EXERCÍCIO 19
#       2 # ================================
# ----> 3 eq = cv2.equalizeHist(gray)
#       4
#       5 plt.imshow(eq, cmap='gray')
#
# NameError: name 'cv2' is not defined

# %%
# EXERCÍCIO 20

_, th = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)

plt.imshow(th, cmap='gray')
plt.title("Threshold binário")
plt.axis('off')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3482/3498525456.py in <cell line: 0>()
#       1 # EXERCÍCIO 20
#       2
# ----> 3 _, th = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)
#       4
#       5 plt.imshow(th, cmap='gray')
#
# NameError: name 'cv2' is not defined
